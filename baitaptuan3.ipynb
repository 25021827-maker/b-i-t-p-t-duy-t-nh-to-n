# %%
n=input("nhập tên của bạn: ")
print("xin chào ",n)

# %%
n=input("nhập tên của bạn: ")

# %%
print("spring\nsummer\nautumn\nwinter")

# %%
n=(input("nhập số: "))
m="".join(reversed(str(n)))
print(m)

# %%
a, b = map(int,input("nhập số: ").split())
a=a^b
b=a^b
a=a^b
print(a, b)

# %%
n=int(input("nhập số: "))
m=(f"{n:b}")
if m.count("1")==1:
    print("True")
else:
    print("False")

# %%
import math
m=int(input("m= "))
n=int(input("n= "))
i=m/n
print(math.ceil(i))

# %%
import math
m=int(input("m= "))
n=int(input("n= "))
i=m/n
print(math.floor(i))

# %%
m=int(input("m= "))
if m%2==0:
    print("even")
else:
    print("odd")

# %%
m=int(input("m= "))
n=int(input("n="))
if m<0 and n<0:
    print("Yes")
if m>0 and n>0:
    print("No")

# %%
a=int(input("a= "))
b=int(input("b= "))
c=int(input("c= "))
if a+b>c and b+c>a and c+a>b:
    print("yes")
else:
    print("no")

# %%
a=int(input("a= "))
b=int(input("b= "))
c=int(input("c= "))
d=int(input("d= "))
if a>b and a>c and a>d:
    print(a)
if b>c and b>d:
    print(b)
if c>d:
    print(c)
else:
    print(d)

# %%
a= int(input("a= "))
b= int(input("b= "))
c=int(input("c= "))
if a+b>c and b+c>a and c+a>b:
    if a==b!=c or b==c!=a or c==a!=b:
        print("tam giác cân")
    elif a==b==c:
        print("tam giác đều")
    else:
        print("tam giác thường")
else:
    print("không phải tam giác")

# %%
n=int(input("năm: "))
if n%100==0:
    if n%400==0:
        print("năm Nhuận")
    else:
        print("năm không nhuận")
else:
    if n%4==0:
        print("năm nhuận")
    else:
        print("năm không nhuận")

# %%
n=int(input("số điện: "))
if n<=50:
    print("tiền điện là: ",n*1500)
elif 50<n<=100:
    print("tiền điện là: ",50*1500+(n-50)*2000)
else:
    print("tiền điện là: ",50*2500+(n-100)*3000)

# %%
a=int(input("a= "))
b=int(input("b= "))
print("nghiệm phương trình bậc nhất 1 ẩn là x= ",-b/a)
